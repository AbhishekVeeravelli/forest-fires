.tfw', 'MOD09A15.TIF.aux.xml', 'MOD09A180.TIF', 'MOD09A179.TIF.aux.xml', 'MOD09A1320.TIF', 'MOD09A1281.TIF', 'MOD09A1508.TIF.ovr', 'MOD09A1557.TIF', 'MOD09A1405.tfw', 'MOD09A192.TIF', 'MOD09A1313.tfw', 'MOD09A1399.TIF.ovr', 'MOD09A1199.TIF.ovr', 'MOD09A1407.TIF.aux.xml', 'MOD09A1493.TIF.aux.xml', 'MOD09A1367.TIF.ovr', 'MOD09A114.TIF.aux.xml', 'MOD0 ...

# %%
from pathlib import Path

tif_folder = Path('/content/Split/Modis_Img').rglob('*.TIF')
files = [x for x in tif_folder]
print(files)
# Out:
# [PosixPath('/content/Split/Modis_Img/MOD09A1245.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1558.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1315.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A198.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1520.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1379.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A18.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1375.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1335.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1505.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A143.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1473.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1550.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1310.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1569.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1184.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1255.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A162.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1157.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1107.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1400.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1191.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1314.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1171.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A170.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1430.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A174.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1250.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1139.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1132.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A173.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1195.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1316.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1533.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1159.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A168.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A180.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1320.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1281.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1557.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A192.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1261.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1378.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1371.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1535.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1194.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1493.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1311.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1232.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A133.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1411.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1256.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A111.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1466.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1189.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1460.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A176.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1532.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1312.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1278.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A171.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1373.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A160.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1100.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1274.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1339.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1109.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A114.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1436.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1503.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1290.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1553.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1370.TIF'), PosixPath('/content/Split/Modis_Img/MOD09A1441.TIF'), PosixPath('/content/ ...

# %%
#from shutil import copyfile
#dst="modistif"
#for src in files:
#  copyfile(src,"modistif")

# %%
#arr1=[]
#for name in arr:
#  if name.startswith("TIF")
#  arr1.append(name)

# %%
import os 
from PIL import Image
import numpy as np

dirname = '/content/modis'
final = []
for fname in os.listdir(dirname):
    im = Image.open(os.path.join(dirname, fname))
    imarray = np.asarray(im)
    final.append(imarray)
print(final[0].shape)

#final = np.asarray(final) # shape = (60000,28,28)
#print(final)
# Out:
# (128, 128)

# %%
dirname2 = '/content/burned'
final2 = []
for fname2 in os.listdir(dirname2):
    im2 = Image.open(os.path.join(dirname2, fname2))
    imarray2 = np.asarray(im2)
    final2.append(imarray2)
   

#final2 = np.asarray(final2) # shape = (60000,28,28)
print(final2)

# %%
#!pip install rasterio
#from osgeo import gdal
#import numpy as np
#import rasterio
#with rasterio.open('/content/Split/Modis_Img/MOD09A10.TIF.aux.xml', GEOREF_SOURCES='INTERNAL') as dataset:
#ds = gdal.Open("/content/Split/Modis_Img/MOD09A10.TIF.aux.xml")
#channel = np.array(ds.GetRasterBand(1).ReadAsArray())

# %%
# mount s3 to dbfs
#ACCESS_KEY = ***********
#SECRET_KEY = ***********
#ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")
#AWS_BUCKET_NAME = ***********
#MOUNT_NAME = "wildFire-Project"
#dbutils.fs.mount("s3a://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
#display(dbutils.fs.ls("/mnt/%s" % MOUNT_NAME))

# %%
######## 2. DATA lOADING ######

# %%
#sample_img_dir = "/mnt/" + MOUNT_NAME + "/image_update"
#sample_mask_dir = "/mnt/" + MOUNT_NAME + "/Label_Update"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
######## 3. DATA PREPROCESSING ######

# %%
#from pyspark.ml.image import ImageSchema
#image_df = ImageSchema.readImages(sample_img_dir)
#mask_df = ImageSchema.readImages(sample_mask_dir)
#image_df = image_df.orderBy('image.origin', ascending=True)
#mask_df = mask_df.orderBy('image.origin', ascending=True)

# %%
# 3.1 Data PACKGING & SHUFFLING

# %%
import numpy as np
import random
random_list = list(range(129))
random.shuffle(random_list)

ids = 249
ims = 390

im_width = 128
im_height = 128

#row_image = image_df.collect()
#row_mask  = mask_df.collect()
#image_arr = np.zeros((129, im_height, im_width, 3), dtype=np.uint8)
#mask_arr = np.zeros((129, im_height, im_width, 3), dtype=np.uint8)
#for i in range(129):
#  image_arr[i] = ImageSchema.toNDArray(row_image[i].image) 
#for i in range(129):
#  mask_arr[i] = ImageSchema.toNDArray(row_mask[i].image)
  
k = 0
image_arr_1 = np.zeros((129, im_height, im_width,3), dtype=np.uint8)
mask_arr_1 = np.zeros((129, im_height, im_width,3), dtype=np.uint8)
for i in random_list:
  image_arr_1[k] = final[i]
  mask_arr_1[k]  = final2[i] 
  k = k + 1

# %%
######## 3.2 DATA PREPROCESSING VARIFICATION ######

# %%
import matplotlib.pyplot as plt
final[0].shape
#print(imarray[5])
plt.imshow(final[0])

# %%
#plt.imshow(mask_arr_1[125])

# %%
######## 3.3 DATA CONVERSION ######

# %%
mean_data1 = np.array(final).mean(axis=0)
mean_data2 = np.array(final2).mean(axis=0)

# %%
# convert data to the 3-D array format
X_data  = final
label  = final2[:][:][:][2]
y_data = label.reshape((label.shape[0], label.shape[1], label.shape[2], 1))
X_data =X_data/ np.max(X_data.astype('float'))
y_data =y_data/ np.max(y_data.astype('float'))

ratio = 0.9  
X_train = X_data[:round(129*ratio)]
y_train = y_data[:round(129*ratio)]
X_test = X_data[round(129*ratio)+1:-1]
Y_test = y_data[round(129*ratio)+1:-1]

# %%
######## 4. MODELING ######

# %%
from keras.datasets import mnist
from keras.layers import  Input,Conv2D,Conv3D,BatchNormalization,Activation,Conv2DTranspose, Conv3DTranspose, MaxPooling2D, MaxPooling3D, concatenate
from keras.models import Model, load_model
from keras.callbacks import CSVLogger, ModelCheckpoint, LearningRateScheduler
from keras.optimizers import Adam
import keras.backend as K
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import mlflow
import mlflow.keras
from keras.callbacks import ModelCheckpoint

# %%
######## 4.1 MODEL SETUP ######

# %%
MODEL_VERSION = '2.5' 
MODEL_NAME = 'Unet'
model_save_path = '/dbfs/mnt/'+MOUNT_NAME+'/'+MODEL_VERSION+'/'+MODEL_NAME
model_Unet = mlflow.keras.load_model(model_save_path)
callbacks = [ModelCheckpoint('model.h5', verbose = 1, save_best_only = True, save_weights_only = True)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create image generator
data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=[0.5, 1.5]
                     )
image_datagen = ImageDataGenerator(**data_gen_args)

seed = 1

def XYaugmentGenerator(X1, y, seed, batch_size):
    genX1 = image_datagen.flow(X1, y, batch_size=batch_size, seed=seed)
    genX2 = image_datagen.flow(y, X1, batch_size=batch_size, seed=seed)
    while True:
        X1i = genX1.next()
        X2i = genX2.next()
        yield X1i[0], X2i[0]

# %%
img_rows, img_cols = im_height, im_width
num_convs_per_layer=2
image_channels=1
num_dim=2
batch_norm=0
num_chans=3
feat_size_0=16
filt_size = (4,4)
max_pooling_size=(2,2)
U_net_depth=4
feat_size_growth=1.5
batchsize=1
feat_size = [int(feat_size_0 * feat_size_growth ** i) for i in range(U_net_depth + 1)]  



def model():
    def Unet_block( feat_size, filt_size, num_convs_per_layer, inputs):
        for i_conv in range(num_convs_per_layer):
            layer=Conv2D(feat_size, kernel_size=filt_size, padding='same', activation='relu')(inputs)     
        if batch_norm:
            return BatchNormalization()(layer)
        else:
            return layer
    
    def encode(inputs):
        unet_layer = [[] for i in range(U_net_depth+1)]
        unet_layer[0] = inputs
        for layer in range(U_net_depth):
            unet_layer[layer] = Unet_block(feat_size[layer], filt_size, num_convs_per_layer, unet_layer[layer])
            unet_layer[layer + 1] = MaxPooling2D(pool_size=max_pooling_size)(unet_layer[layer])
        return unet_layer
    
    def decode(unet_layer):
        for layer in range(U_net_depth, 0, -1):
            unet_layer[layer] = Unet_block(feat_size[layer], filt_size, num_convs_per_layer, unet_layer[layer])
            trans_layer = Conv2DTranspose(feat_size[layer - 1], kernel_size=filt_size, strides=max_pooling_size, padding='same', activation='relu')(unet_layer[layer])
            if K.int_shape(trans_layer)[1]==K.int_shape(unet_layer[layer - 1])[1]:
                unet_layer[layer - 1] = concatenate([trans_layer, unet_layer[layer - 1]])
            else:
                K.resize_images(trans_layer,K.int_shape(unet_layer[layer - 1])[1], K.int_shape(unet_layer[layer - 1])[2], data_format='channels_last', interpolation='nearest' )
                unet_layer[layer - 1] = concatenate([trans_layer, unet_layer[layer - 1]])
        unet_layer[0] = Unet_block(feat_size[0], filt_size, num_convs_per_layer, unet_layer[0])
        return unet_layer[0]
        
    inputs = Input(shape=(img_rows, img_cols, num_chans))        
    last_layer = decode(encode(inputs))                                                                       
    last_layer = Conv2D(1, (1, 1), activation='sigmoid')(last_layer)
    return Model(inputs=[inputs], outputs=[last_layer])

# %%
######## 4.2 TRAINING ######

# %%
model_Unet=model()
model_Unet.summary()
model_Unet.compile(loss='binary_crossentropy', optimizer='Adam')
model_Unet.fit(X_train, y_train, epochs=5, batch_size=batchsize,  validation_data=(X_test,Y_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Model: &#34;model_1&#34;
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 480, 720, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 480, 720, 16) 784         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 480, 720, 16) 4112        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 240, 360, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 240, 360, 24) 6168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 240, 360, 24) 9240        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 120, 180, 24) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 120, 180, 36) 13860       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 120, 180, 36) 20772       conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 60, 90, 36)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 60, 90, 54)   31158       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 90, 54)   46710       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 30, 45, 54)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 30, 45, 81)   70065       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 45, 81)   105057      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 60, 90, 54)   70038       conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 90, 108)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 60, 90, 54)   93366       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 90, 54)   46710       conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 120, 180, 36) 31140       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 180, 72) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 120, 180, 36) 41508       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 180, 36) 20772       conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 240, 360, 24) 13848       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 360, 48) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 240, 360, 24) 18456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 360, 24) 9240        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 480, 720, 16) 6160        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 480, 720, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 480, 720, 16) 8208        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 480, 720, 16) 4112        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 480, 720, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 671,501
# Trainable params: 671,501
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 116 samples, validate on 11 samples
# Epoch 1/5
# 116/116 [==============================] - 436s 4s/step - loss: 0.5284 - val_loss: 0.3881
# Epoch 2/5
#  62/116 [===============&gt;..............] - ETA: 3:1

# %%
######## 5. DATA POSTPROCESSING ######

# %%
preds_train = model_Unet.predict(X_train, verbose=1)
preds_val = model_Unet.predict(X_test, verbose=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# 116/116 [==============================] - 60s 514ms/step
# 11/11 [==============================] - 6s 512ms/step
# </div>

# %%
preds_train_t = (preds_train > 0.25).astype(np.uint8)
preds_val_t = (preds_val > 0.25).astype(np.uint8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
######## 6. RESULT VISUALIZATION ######

# %%
def conv_float_int(image):
    return ((image-np.min(image))/(np.max(image)-np.min(image))*255).astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import cv2

# visualization
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(conv_float_int(X[ix]))
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Raw')
    ax[1].imshow(conv_float_int(y[ix, :, :, 0]))
    ax[1].set_title('mask')

    ax[2].imshow(conv_float_int(preds[ix, :, :, 0]), vmin=0, vmax=255)
    if has_mask:
        ax[2].contour(conv_float_int(y[ix, :, :, 0]), colors='k', levels=[0.5])
    ax[2].set_title('mask Predicted')
    ret2,th1 = cv2.threshold(conv_float_int(preds[ix, :, :, 0]).astype('uint8'), 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    ax[3].imshow(conv_float_int(th1), vmin=0, vmax=255)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('mask Predicted binary');
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plot_sample(X_test, Y_test, preds_val, preds_val_t, ix=5)

# %%
model.train()
# Out:
# 0.85876567
